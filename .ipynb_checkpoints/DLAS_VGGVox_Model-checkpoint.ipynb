# %% [markdown]
# # VGGVox

# %%
import pandas as pd
import os
import numpy as np
import re

# %%
if not os.path.exists('VGGVox-PyTorch'):
    ! git clone https://github.com/Derpimort/VGGVox-PyTorch.git
    if not os.path.exists('VGGVox-PyTorch/dataset'):
        os.system('mkdir dataset')
    os.system('rm -r VGGVox-PyTorch/data')
    os.system('cp -r dataset/ VGGVox-PyTorch/dataset/' )
    os.chdir('VGGVox-PyTorch')
    ! pip install -r requirements.txt
    
else:
    if not os.path.exists('VGGVox-PyTorch/dataset'):
        os.system('mkdir dataset')
    os.system('rm -r VGGVox-PyTorch/data')
    os.system(' cp -r dataset/ VGGVox-PyTorch/dataset/' )
    os.chdir('VGGVox-PyTorch')
    ! pip install -r requirements.txt
# Out:
# rm: VGGVox-PyTorch/data: No such file or directory
# Requirement already satisfied: numpy in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.20.3)
# Requirement already satisfied: scipy in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.7.1)
# Requirement already satisfied: pandas in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.3.4)
# Requirement already satisfied: torch in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (1.11.0)
# Requirement already satisfied: torchvision in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: matplotlib in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: tqdm in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (4.62.3)
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: torchsummary in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2021.3)
# Requirement already satisfied: typing-extensions in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (3.10.0.2)
# Requirement already satisfied: requests in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 5)) (2.26.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from torchvision->-r requirements.txt (line 5)) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: six in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision->-r requirements.txt (line 5)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision->-r requirements.txt (line 5)) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages (from requests->torchvision->-r requirements.txt (line 5)) (3.2)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
import torch
from torch.utils.data import Subset, Dataset, DataLoader
from tqdm.auto import tqdm
from vggm import VGGM
import argparse
from train import AudioDataset, accuracy, ppdf, LOCAL_DATA_DIR, MODEL_DIR

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
from sklearn.manifold import TSNE
import time
# %matplotlib inline

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model=VGGM(1251)
model.load_state_dict(torch.load(MODEL_DIR+"VGGM300_BEST_140_81.99.pth", map_location=device))
model.to(device)
model.eval()

### This is to extract an activation from one layer ...
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

# %%
DATA_DIR = '/Users/isabel.rodriguez/Desktop/Isa/MUIT - Machine Learning/DLAS/project/VGGVox-PyTorch'

df = pd.read_csv('./dataset/labels.csv')

Datasets={"test":AudioDataset(df, DATA_DIR, is_train=False)}

Dataloaders={i:DataLoader(Datasets[i], batch_size=1, shuffle=True, num_workers=2) for i in Datasets}

embedding_arr = []

for audio, labels in Dataloaders['test']:
        audio = audio.to(device)
        labels = labels.to(device)
        model.classifier.fc7.register_forward_hook(get_activation('fc7'))
        outputs = model(audio)

        embedding_arr.append(activation['fc7'].cpu().numpy().reshape(-1))

df['Embeddings'] = pd.Series(embedding_arr)

# %%
df
# Out:
#                                  Path                   Filename  Label  \
# 0   dataset/AVPEPUDEAC0001_pataka.wav  AVPEPUDEAC0001_pataka.wav      0
# 1   dataset/AVPEPUDEAC0003_pataka.wav  AVPEPUDEAC0003_pataka.wav      0
# 2   dataset/AVPEPUDEAC0004_pataka.wav  AVPEPUDEAC0004_pataka.wav      0
# 3   dataset/AVPEPUDEAC0005_pataka.wav  AVPEPUDEAC0005_pataka.wav      0
# 4   dataset/AVPEPUDEAC0006_pataka.wav  AVPEPUDEAC0006_pataka.wav      0
# ..                                ...                        ...    ...
# 95   dataset/AVPEPUDEA0055_pataka.wav   AVPEPUDEA0055_pataka.wav      1
# 96   dataset/AVPEPUDEA0056_pataka.wav   AVPEPUDEA0056_pataka.wav      1
# 97   dataset/AVPEPUDEA0057_pataka.wav   AVPEPUDEA0057_pataka.wav      1
# 98   dataset/AVPEPUDEA0058_pataka.wav   AVPEPUDEA0058_pataka.wav      1
# 99   dataset/AVPEPUDEA0059_pataka.wav   AVPEPUDEA0059_pataka.wav      1
#
#                                            Embeddings
# 0   [-2.2574333e-11, -4.0789344e-11, -3.784933e-10...
# 1   [-2.5480656e-11, -4.7625816e-11, -4.2545373e-1...
# 2   [-2.7231689e-11, -5.0361847e-11, -4.7508525e-1...
# 3   [-2.9902917e-11, -5.3089137e-11, -4.4072018e-1...
# 4   [-2.3982026e-11, -4.525018e-11, -4.2867246e-10...
# ..                                                ...
# 95  [-2.597591e-11, -4.8046504e-11, -4.096229e-10,...
# 96  [-2.7596307e-11, -5.3557946e-11, -4.765024e-10...
# 97  [-2.212378e-11, -4.1993617e-11, -4.2437104e-10...
# 98  [-2.771281e-11, -5.5143216e-11, -5.077024e-10,...
# 99  [-2.2376255e-11, -4.154574e-11, -3.9141812e-10...
#
# [100 rows x 4 columns]

# %%
df["Pred_Label"] = 0

speaker_t1 = 0
speaker_t2 = 1
embedding_1 = df[df['Label']== speaker_t1].iloc[0]['Embeddings']
embedding_2 = df[df['Label']== speaker_t2].iloc[0]['Embeddings']

similarity = cosine_similarity(embedding_1.reshape(1,-1), embedding_2.reshape(1,-1))
cosine_distance = 1 - similarity

print('Cosine similarity: ', similarity, ' cosine distance: ', cosine_distance)


print('\n\n-----------------Speaker: ', speaker_t1)
print(df[df['Label']== speaker_t1].iloc[0],'\n')


print('-----------------Speaker: ', speaker_t2)
print(df[df['Label']== speaker_t2].iloc[0])
# Out:
# Cosine similarity:  [[0.84896415]]  cosine distance:  [[0.15103585]]
#
#
# -----------------Speaker:  0
# Path                          dataset/AVPEPUDEAC0001_pataka.wav
# Filename                              AVPEPUDEAC0001_pataka.wav
# Label                                                         0
# Embeddings    [-2.2574333e-11, -4.0789344e-11, -3.784933e-10...
# Pred_Label                                                    0
# Name: 0, dtype: object
#
# -----------------Speaker:  1
# Path                           dataset/AVPEPUDEA0001_petaka.wav
# Filename                               AVPEPUDEA0001_petaka.wav
# Label                                                         1
# Embeddings    [-3.1678073e-11, -5.4082627e-11, -4.94649e-10,...
# Pred_Label                                                    0
# Name: 50, dtype: object

# %%
for i in range (0, len(df['Embeddings'])):
    if i!=0 and i !=50:
        similarity_sp1 = cosine_similarity(embedding_1.reshape(1,-1), df['Embeddings'][i].reshape(1,-1))
        cosine_distance_sp1 = 1 - similarity_sp1
        similarity_sp2 = cosine_similarity(embedding_2.reshape(1,-1), df['Embeddings'][i].reshape(1,-1))
        cosine_distance_sp2 = 1 - similarity_sp2

        print('Cosine similarity with speaker 1: ', similarity_sp1, ' cosine distance with speaker 1: ', cosine_distance_sp1)
        print('Cosine similarity with speaker 2: ', similarity_sp2, ' cosine distance with speaker 2: ', cosine_distance_sp2)
        
        if min(cosine_distance_sp1,cosine_distance_sp2) == cosine_distance_sp1:
            df['Pred_Label'][i] = 0
        elif min(cosine_distance_sp1,cosine_distance_sp2) == cosine_distance_sp2:
            df['Pred_Label'][i] = 1
        else:
            df['Pred_Label'][i] = np.nan
    else:
        df['Pred_Label'].iloc[0] = 0
        df['Pred_Label'].iloc[50] = 1
# Out:
# Cosine similarity with speaker 1:  [[0.831773]]  cosine distance with speaker 1:  [[0.16822702]]
# Cosine similarity with speaker 2:  [[0.8771102]]  cosine distance with speaker 2:  [[0.12288982]]
# Cosine similarity with speaker 1:  [[0.9000213]]  cosine distance with speaker 1:  [[0.09997869]]
# Cosine similarity with speaker 2:  [[0.9129715]]  cosine distance with speaker 2:  [[0.0870285]]
# Cosine similarity with speaker 1:  [[0.8946378]]  cosine distance with speaker 1:  [[0.10536218]]
# Cosine similarity with speaker 2:  [[0.8330828]]  cosine distance with speaker 2:  [[0.1669172]]
# Cosine similarity with speaker 1:  [[0.79728687]]  cosine distance with speaker 1:  [[0.20271313]]
# Cosine similarity with speaker 2:  [[0.86538595]]  cosine distance with speaker 2:  [[0.13461405]]
# Cosine similarity with speaker 1:  [[0.939069]]  cosine distance with speaker 1:  [[0.06093103]]
# Cosine similarity with speaker 2:  [[0.85344774]]  cosine distance with speaker 2:  [[0.14655226]]
# Cosine similarity with speaker 1:  [[0.85946524]]  cosine distance with speaker 1:  [[0.14053476]]
# Cosine similarity with speaker 2:  [[0.88300276]]  cosine distance with speaker 2:  [[0.11699724]]
# Cosine similarity with speaker 1:  [[0.8380375]]  cosine distance with speaker 1:  [[0.16196251]]
# Cosine similarity with speaker 2:  [[0.86989343]]  cosine distance with speaker 2:  [[0.13010657]]
# Cosine similarity with speaker 1:  [[0.8346288]]  cosine distance with speaker 1:  [[0.16537118]]
# Cosine similarity with speaker 2:  [[0.92131823]]  cosine distance with speaker 2:  [[0.07868177]]
# Cosine similarity with speaker 1:  [[0.93739367]]  cosine distance with speaker 1:  [[0.06260633]]
# Cosine similarity with speaker 2:  [[0.8621092]]  cosine distance with speaker 2:  [[0.13789082]]
# Cosine similarity with speaker 1:  [[0.8745589]]  cosine distance with speaker 1:  [[0.12544107]]
# Cosine similarity with speaker 2:  [[0.9129556]]  cosine distance with speaker 2:  [[0.08704442]]
# Cosine similarity with speaker 1:  [[0.76614374]]  cosine distance with speaker 1:  [[0.23385626]]
# Cosine similarity with speaker 2:  [[0.84208745]]  cosine distance with speaker 2:  [[0.15791255]]
# Cosine similarity with speaker 1:  [[0.8123966]]  cosine distance with speaker 1:  [[0.18760341]]
# Cosine similarity with speaker 2:  [[0.8768202]]  cosine distance with speaker 2:  [[0.12317979]]
# Cosine similarity with speaker 1:  [[0.82825696]]  cosine distance with speaker 1:  [[0.17174304]]
# Cosine similarity with speaker 2:  [[0.8912714]]  cosine distance with speaker 2:  [[0.10872859]]
# Cosine similarity with speaker 1:  [[0.8545612]]  cosine distance with speaker 1:  [[0.14543879]]
# Cosine similarity with speaker 2:  [[0.87436473]]  cosine distance with speaker 2:  [[0.12563527]]
# Cosine similarity with speaker 1:  [[0.8355987]]  cosine distance with speaker 1:  [[0.1644013]]
# Cosine similarity with speaker 2:  [[0.87354475]]  cosine distance with speaker 2:  [[0.12645525]]
# Cosine similarity with speaker 1:  [[0.74921167]]  cosine distance with speaker 1:  [[0.25078833]]
# Cosine similarity with speaker 2:  [[0.89260805]]  cosine distance with speaker 2:  [[0.10739195]]
# Cosine similarity with speaker 1:  [[0.8398596]]  cosine distance with speaker 1:  [[0.1601404]]
# Cosine similarity with speaker 2:  [[0.8532038]]  cosine distance with speaker 2:  [[0.14679623]]
# Cosine similarity with speaker 1:  [[0.79158354]]  cosine distance with speaker 1:  [[0.20841646]]
# Cosine similarity with speaker 2:  [[0.8557351]]  cosine distance with speaker 2:  [[0.14426488]]
# Cosine similarity with speaker 1:  [[0.8870182]]  cosine distance with speaker 1:  [[0.1129818]]
# Cosine similarity with speaker 2:  [[0.86816376]]  cosine distance with speaker 2:  [[0.13183624]]
# Cosine similarity with speaker 1:  [[0.871048]]  cosine distance with speaker 1:  [[0.12895203]]
# Cosine similarity with speaker 2:  [[0.83541495]]  cosine distance with speaker 2:  [[0.16458505]]
# Cosine similarity with speaker 1:  [[0.81256115]]  cosine distance with speaker 1:  [[0.18743885]]
# Cosine similarity with speaker 2:  [[0.8620926]]  cosine distance with speaker 2:  [[0.13790739]]
# Cosine similarity with speaker 1:  [[0.868494]]  cosine distance with speaker 1:  [[0.13150603]]
# Cosine similarity with speaker 2:  [[0.8867464]]  cosine distance with speaker 2:  [[0.11325359]]
# Cosine similarity with speaker 1:  [[0.7865627]]  cosine distance with speaker 1:  [[0.21343732]]
# Cosine similarity with speaker 2:  [[0.8673283]]  cosine distance with speaker 2:  [[0.13267171]]
# Cosine similarity with speaker 1:  [[0.7657946]]  cosine distance with speaker 1:  [[0.23420542]]
# Cosine similarity with speaker 2:  [[0.859282]]  cosine distance with speaker 2:  [[0.14071798]]
# Cosine similarity with speaker 1:  [[0.8356656]]  cosine distance with speaker 1:  [[0.16433442]]
# Cosine similarity with speaker 2:  [[0.8585582]]  cosine distance with speaker 2:  [[0.14144182]]
# Cosine similarity with speaker 1:  [[0.88741595]]  cosine distance with speaker 1:  [[0.11258405]]
# Cosine similarity with speaker 2:  [[0.81547225]]  cosine distance with speaker 2:  [[0.18452775]]
# Cosine similarity with speaker 1:  [[0.8663943]]  cosine distance with speaker 1:  [[0.13360572]]
# Cosine similarity with speaker 2:  [[0.8632228]]  cosine distance with speaker 2:  [[0.13677722]]
# Cosine similarity with speaker 1:  [[0.87174433]]  cosine distance with speaker 1:  [[0.12825567]]
# Cosine similarity with speaker 2:  [[0.85491747]]  cosine distance with speaker 2:  [[0.14508253]]
# Cosine similarity with speaker 1:  [[0.9593721]]  cosine distance with speaker 1:  [[0.0406279]]
# Cosine similarity with speaker 2:  [[0.88204896]]  cosine distance with speaker 2:  [[0.11795104]]
# Cosine similarity with speaker 1:  [[0.77257717]]  cosine distance with speaker 1:  [[0.22742283]]
# Cosine similarity with speaker 2:  [[0.82029164]]  cosine distance with speaker 2:  [[0.17970836]]
# Cosine similarity with speaker 1:  [[0.83757925]]  cosine distance with speaker 1:  [[0.16242075]]
# Cosine similarity with speaker 2:  [[0.8776256]]  cosine distance with speaker 2:  [[0.12237442]]
# Cosine similarity with speaker 1:  [[0.9447794]]  cosine distance with speaker 1:  [[0.0552206]]
# Cosine similarity with speaker 2:  [[0.8959396]]  cosine distance with speaker 2:  [[0.10406041]]
# Cosine similarity with speaker 1:  [[0.9178283]]  cosine distance with speaker 1:  [[0.08217168]]
# Cosine similarity with speaker 2:  [[0.89420503]]  cosine distance with speaker 2:  [[0.10579497]]
# Cosine similarity with speaker 1:  [[0.7956202]]  cosine distance with speaker 1:  [[0.2043798]]
# Cosine similarity with speaker 2:  [[0.79604584]]  cosine distance with speaker 2:  [[0.20395416]]
# Cosine similarity with speaker 1:  [[0.8328345]]  cosine distance with speaker 1:  [[0.16716552]]
# Cosine similarity with speaker 2:  [[0.8586764]]  cosine distance with speaker 2:  [[0.14132363]]
# Cosine similarity with speaker 1:  [[0.8062174]]  cosine distance with speaker 1:  [[0.19378263]]
# Cosine similarity with speaker 2:  [[0.92549026]]  cosine distance with speaker 2:  [[0.07450974]]
# Cosine similarity with speaker 1:  [[0.85055673]]  cosine distance with speaker 1:  [[0.14944327]]
# Cosine similarity with speaker 2:  [[0.8870821]]  cosine distance with speaker 2:  [[0.1129179]]
# Cosine similarity with speaker 1:  [[0.81579757]]  cosine distance with speaker 1:  [[0.18420243]]
# Cosine similarity with speaker 2:  [[0.85614574]]  cosine distance with speaker 2:  [[0.14385426]]
# Cosine similarity with speaker 1:  [[0.81462824]]  cosine distance with speaker 1:  [[0.18537176]]
# Cosine similarity with speaker 2:  [[0.89643484]]  cosine distance with speaker 2:  [[0.10356516]]
# Cosine similarity with speaker 1:  [[0.88223755]]  cosine distance with speaker 1:  [[0.11776245]]
# Cosine similarity with speaker 2:  [[0.8675526]]  cosine distance with speaker 2:  [[0.13244742]]
# Cosine similarity with speaker 1:  [[0.893267]]  cosine distance with speaker 1:  [[0.10673302]]
# Cosine similarity with speaker 2:  [[0.9238191]]  cosine distance with speaker 2:  [[0.07618088]]
# Cosine similarity with speaker 1:  [[0.8825834]]  cosine distance with speaker 1:  [[0.11741662]]
# Cosine similarity with speaker 2:  [[0.910071]]  cosine distance with speaker 2:  [[0.08992898]]
# Cosine similarity with speaker 1:  [[0.8373724]]  cosine distance with speaker 1:  [[0.16262758]]
# Cosine similarity with speaker 2:  [[0.8909005]]  cosine distance with speaker 2:  [[0.10909951]]
# Cosine similarity with speaker 1:  [[0.9122836]]  cosine distance with speaker 1:  [[0.0877164]]
# Cosine similarity with speaker 2:  [[0.9112832]]  cosine distance with speaker 2:  [[0.0887168]]
# Cosine similarity with speaker 1:  [[0.8269699]]  cosine distance with speaker 1:  [[0.17303008]]
# Cosine similarity with speaker 2:  [[0.8478503]]  cosine distance with speaker 2:  [[0.15214968]]
# Cosine similarity with speaker 1:  [[0.804333]]  cosine distance with speaker 1:  [[0.19566703]]
# Cosine similarity with speaker 2:  [[0.84506035]]  cosine distance with speaker 2:  [[0.15493965]]
# Cosine similarity with speaker 1:  [[0.8496505]]  cosine distance with speaker 1:  [[0.1503495]]
# Cosine similarity with speaker 2:  [[0.88845325]]  cosine distance with speaker 2:  [[0.11154675]]
# Cosine similarity with speaker 1:  [[0.87202513]]  cosine distance with speaker 1:  [[0.12797487]]
# Cosine similarity with speaker 2:  [[0.87866217]]  cosine distance with speaker 2:  [[0.12133783]]
# Cosine similarity with speaker 1:  [[0.8634513]]  cosine distance with speaker 1:  [[0.1365487]]
# Cosine similarity with speaker 2:  [[0.8931349]]  cosine distance with speaker 2:  [[0.10686511]]
# Cosine similarity with speaker 1:  [[0.8879131]]  cosine distance with speaker 1:  [[0.11208689]]
# Cosine similarity with speaker 2:  [[0.8311199]]  cosine distance with speaker 2:  [[0.1688801]]
# Cosine similarity with speaker 1:  [[0.8402356]]  cosine distance with speaker 1:  [[0.15976441]]
# Cosine similarity with speaker 2:  [[0.90575844]]  cosine distance with speaker 2:  [[0.09424156]]
# Cosine similarity with speaker 1:  [[0.8840687]]  cosine distance with speaker 1:  [[0.11593127]]
# Cosine similarity with speaker 2:  [[0.8597885]]  cosine distance with speaker 2:  [[0.14021152]]
# Cosine similarity with speaker 1:  [[0.8594345]]  cosine distance with speaker 1:  [[0.14056551]]
# Cosine similarity with speaker 2:  [[0.8908161]]  cosine distance with speaker 2:  [[0.10918391]]
# Cosine similarity with speaker 1:  [[0.87383413]]  cosine distance with speaker 1:  [[0.12616587]]
# Cosine similarity with speaker 2:  [[0.8645916]]  cosine distance with speaker 2:  [[0.1354084]]
# Cosine similarity with speaker 1:  [[0.8394336]]  cosine distance with speaker 1:  [[0.16056639]]
# Cosine similarity with speaker 2:  [[0.8846103]]  cosine distance with speaker 2:  [[0.1153897]]
# Cosine similarity with speaker 1:  [[0.8277085]]  cosine distance with speaker 1:  [[0.17229152]]
# Cosine similarity with speaker 2:  [[0.89669144]]  cosine distance with speaker 2:  [[0.10330856]]
# Cosine similarity with speaker 1:  [[0.8583386]]  cosine distance with speaker 1:  [[0.1416614]]
# Cosine similarity with speaker 2:  [[0.8995983]]  cosine distance with speaker 2:  [[0.1004017]]
# Cosine similarity with speaker 1:  [[0.82649946]]  cosine distance with speaker 1:  [[0.17350054]]
# Cosine similarity with speaker 2:  [[0.86889577]]  cosine distance with speaker 2:  [[0.13110423]]
# Cosine similarity with speaker 1:  [[0.8266386]]  cosine distance with speaker 1:  [[0.17336142]]
# Cosine similarity with speaker 2:  [[0.82337916]]  cosine distance with speaker 2:  [[0.17662084]]
# Cosine similarity with speaker 1:  [[0.87051195]]  cosine distance with speaker 1:  [[0.12948805]]
# Cosine similarity with speaker 2:  [[0.90672195]]  cosine distance with speaker 2:  [[0.09327805]]
# Cosine similarity with speaker 1:  [[0.87334615]]  cosine distance with speaker 1:  [[0.12665385]]
# Cosine similarity with speaker 2:  [[0.86587995]]  cosine distance with speaker 2:  [[0.13412005]]
# Cosine similarity with speaker 1:  [[0.85365486]]  cosine distance with speaker 1:  [[0.14634514]]
# Cosine similarity with speaker 2:  [[0.93967915]]  cosine distance with speaker 2:  [[0.06032085]]
# Cosine similarity with speaker 1:  [[0.79583335]]  cosine distance with speaker 1:  [[0.20416665]]
# Cosine similarity with speaker 2:  [[0.849564]]  cosine distance with speaker 2:  [[0.15043598]]
# Cosine similarity with speaker 1:  [[0.8447143]]  cosine distance with speaker 1:  [[0.15528572]]
# Cosine similarity with speaker 2:  [[0.89781594]]  cosine distance with speaker 2:  [[0.10218406]]
# Cosine similarity with speaker 1:  [[0.81826746]]  cosine distance with speaker 1:  [[0.18173254]]
# Cosine similarity with speaker 2:  [[0.86484945]]  cosine distance with speaker 2:  [[0.13515055]]
# Cosine similarity with speaker 1:  [[0.85065556]]  cosine distance with speaker 1:  [[0.14934444]]
# Cosine similarity with speaker 2:  [[0.9097847]]  cosine distance with speaker 2:  [[0.09021533]]
# Cosine similarity with speaker 1:  [[0.84175974]]  cosine distance with speaker 1:  [[0.15824026]]
# Cosine similarity with speaker 2:  [[0.8608551]]  cosine distance with speaker 2:  [[0.1391449]]
# Cosine similarity with speaker 1:  [[0.8798141]]  cosine distance with speaker 1:  [[0.12018591]]
# Cosine similarity with speaker 2:  [[0.8611702]]  cosine distance with speaker 2:  [[0.13882983]]
# Cosine similarity with speaker 1:  [[0.8230078]]  cosine distance with speaker 1:  [[0.17699218]]
# Cosine similarity with speaker 2:  [[0.9166963]]  cosine distance with speaker 2:  [[0.08330369]]
# Cosine similarity with speaker 1:  [[0.8279621]]  cosine distance with speaker 1:  [[0.1720379]]
# Cosine similarity with speaker 2:  [[0.9069443]]  cosine distance with speaker 2:  [[0.09305573]]
# Cosine similarity with speaker 1:  [[0.8613031]]  cosine distance with speaker 1:  [[0.13869691]]
# Cosine similarity with speaker 2:  [[0.9054557]]  cosine distance with speaker 2:  [[0.09454429]]
# Cosine similarity with speaker 1:  [[0.8258452]]  cosine distance with speaker 1:  [[0.17415482]]
# Cosine similarity with speaker 2:  [[0.84449863]]  cosine distance with speaker 2:  [[0.15550137]]
# Cosine similarity with speaker 1:  [[0.8152314]]  cosine distance with speaker 1:  [[0.18476862]]
# Cosine similarity with speaker 2:  [[0.875443]]  cosine distance with speaker 2:  [[0.12455702]]
# Cosine similarity with speaker 1:  [[0.93237966]]  cosine distance with speaker 1:  [[0.06762034]]
# Cosine similarity with speaker 2:  [[0.8643031]]  cosine distance with speaker 2:  [[0.13569689]]
# Cosine similarity with speaker 1:  [[0.82136065]]  cosine distance with speaker 1:  [[0.17863935]]
# Cosine similarity with speaker 2:  [[0.8985782]]  cosine distance with speaker 2:  [[0.10142177]]
# Cosine similarity with speaker 1:  [[0.8434995]]  cosine distance with speaker 1:  [[0.15650052]]
# Cosine similarity with speaker 2:  [[0.91190726]]  cosine distance with speaker 2:  [[0.08809274]]
# Cosine similarity with speaker 1:  [[0.8850291]]  cosine distance with speaker 1:  [[0.11497092]]
# Cosine similarity with speaker 2:  [[0.87234974]]  cosine distance with speaker 2:  [[0.12765026]]
# Cosine similarity with speaker 1:  [[0.86086965]]  cosine distance with speaker 1:  [[0.13913035]]
# Cosine similarity with speaker 2:  [[0.8875386]]  cosine distance with speaker 2:  [[0.11246139]]
# Cosine similarity with speaker 1:  [[0.8559184]]  cosine distance with speaker 1:  [[0.1440816]]
# Cosine similarity with speaker 2:  [[0.8589172]]  cosine distance with speaker 2:  [[0.14108282]]
# Cosine similarity with speaker 1:  [[0.8607809]]  cosine distance with speaker 1:  [[0.1392191]]
# Cosine similarity with speaker 2:  [[0.9239702]]  cosine distance with speaker 2:  [[0.07602978]]
# Cosine similarity with speaker 1:  [[0.8363663]]  cosine distance with speaker 1:  [[0.1636337]]
# Cosine similarity with speaker 2:  [[0.8852693]]  cosine distance with speaker 2:  [[0.11473072]]
# Cosine similarity with speaker 1:  [[0.83635056]]  cosine distance with speaker 1:  [[0.16364944]]
# Cosine similarity with speaker 2:  [[0.83303505]]  cosine distance with speaker 2:  [[0.16696495]]
# Cosine similarity with speaker 1:  [[0.9321227]]  cosine distance with speaker 1:  [[0.06787729]]
# Cosine similarity with speaker 2:  [[0.88944197]]  cosine distance with speaker 2:  [[0.11055803]]
# Cosine similarity with speaker 1:  [[0.84864354]]  cosine distance with speaker 1:  [[0.15135646]]
# Cosine similarity with speaker 2:  [[0.84481776]]  cosine distance with speaker 2:  [[0.15518224]]
# Cosine similarity with speaker 1:  [[0.84916484]]  cosine distance with speaker 1:  [[0.15083516]]
# Cosine similarity with speaker 2:  [[0.85787714]]  cosine distance with speaker 2:  [[0.14212286]]
# Cosine similarity with speaker 1:  [[0.8706974]]  cosine distance with speaker 1:  [[0.12930262]]
# Cosine similarity with speaker 2:  [[0.89210886]]  cosine distance with speaker 2:  [[0.10789114]]
# Cosine similarity with speaker 1:  [[0.79405]]  cosine distance with speaker 1:  [[0.20595002]]
# Cosine similarity with speaker 2:  [[0.8814179]]  cosine distance with speaker 2:  [[0.11858213]]
# Cosine similarity with speaker 1:  [[0.8383957]]  cosine distance with speaker 1:  [[0.16160429]]
# Cosine similarity with speaker 2:  [[0.91523254]]  cosine distance with speaker 2:  [[0.08476746]]
# Cosine similarity with speaker 1:  [[0.88163817]]  cosine distance with speaker 1:  [[0.11836183]]
# Cosine similarity with speaker 2:  [[0.888242]]  cosine distance with speaker 2:  [[0.11175799]]
# Cosine similarity with speaker 1:  [[0.853566]]  cosine distance with speaker 1:  [[0.14643401]]
# Cosine similarity with speaker 2:  [[0.881171]]  cosine distance with speaker 2:  [[0.11882901]]
# Cosine similarity with speaker 1:  [[0.85026103]]  cosine distance with speaker 1:  [[0.14973897]]
# Cosine similarity with speaker 2:  [[0.9087245]]  cosine distance with speaker 2:  [[0.09127551]]
# Cosine similarity with speaker 1:  [[0.8224924]]  cosine distance with speaker 1:  [[0.17750758]]
# Cosine similarity with speaker 2:  [[0.8408259]]  cosine distance with speaker 2:  [[0.15917408]]
# Cosine similarity with speaker 1:  [[0.85141313]]  cosine distance with speaker 1:  [[0.14858687]]
# Cosine similarity with speaker 2:  [[0.8402113]]  cosine distance with speaker 2:  [[0.15978873]]
# Cosine similarity with speaker 1:  [[0.8098749]]  cosine distance with speaker 1:  [[0.19012511]]
# Cosine similarity with speaker 2:  [[0.84158283]]  cosine distance with speaker 2:  [[0.15841717]]
# Cosine similarity with speaker 1:  [[0.91696]]  cosine distance with speaker 1:  [[0.08304]]
# Cosine similarity with speaker 2:  [[0.87285054]]  cosine distance with speaker 2:  [[0.12714946]]
# Cosine similarity with speaker 1:  [[0.8107393]]  cosine distance with speaker 1:  [[0.18926072]]
# Cosine similarity with speaker 2:  [[0.8577539]]  cosine distance with speaker 2:  [[0.14224613]]
# Cosine similarity with speaker 1:  [[0.8441647]]  cosine distance with speaker 1:  [[0.15583527]]
# Cosine similarity with speaker 2:  [[0.8616675]]  cosine distance with speaker 2:  [[0.13833249]]
# Cosine similarity with speaker 1:  [[0.84641516]]  cosine distance with speaker 1:  [[0.15358484]]
# Cosine similarity with speaker 2:  [[0.8666973]]  cosine distance with speaker 2:  [[0.13330269]]
# /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /Users/isabel.rodriguez/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 0
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1
# /var/folders/tw/_h7yq1ks6m93h0ly9bzf7d9h0000gn/T/ipykernel_49393/3631717452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pred_Label'][i] = 1

# %%
df
# Out:
#                                  Path                   Filename  Label  \
# 0   dataset/AVPEPUDEAC0001_pataka.wav  AVPEPUDEAC0001_pataka.wav      0
# 1   dataset/AVPEPUDEAC0003_pataka.wav  AVPEPUDEAC0003_pataka.wav      0
# 2   dataset/AVPEPUDEAC0004_pataka.wav  AVPEPUDEAC0004_pataka.wav      0
# 3   dataset/AVPEPUDEAC0005_pataka.wav  AVPEPUDEAC0005_pataka.wav      0
# 4   dataset/AVPEPUDEAC0006_pataka.wav  AVPEPUDEAC0006_pataka.wav      0
# ..                                ...                        ...    ...
# 95   dataset/AVPEPUDEA0055_pataka.wav   AVPEPUDEA0055_pataka.wav      1
# 96   dataset/AVPEPUDEA0056_pataka.wav   AVPEPUDEA0056_pataka.wav      1
# 97   dataset/AVPEPUDEA0057_pataka.wav   AVPEPUDEA0057_pataka.wav      1
# 98   dataset/AVPEPUDEA0058_pataka.wav   AVPEPUDEA0058_pataka.wav      1
# 99   dataset/AVPEPUDEA0059_pataka.wav   AVPEPUDEA0059_pataka.wav      1
#
#                                            Embeddings  Pred_Label
# 0   [-2.2574333e-11, -4.0789344e-11, -3.784933e-10...           0
# 1   [-2.5480656e-11, -4.7625816e-11, -4.2545373e-1...           1
# 2   [-2.7231689e-11, -5.0361847e-11, -4.7508525e-1...           1
# 3   [-2.9902917e-11, -5.3089137e-11, -4.4072018e-1...           0
# 4   [-2.3982026e-11, -4.525018e-11, -4.2867246e-10...           1
# ..                                                ...         ...
# 95  [-2.597591e-11, -4.8046504e-11, -4.096229e-10,...           1
# 96  [-2.7596307e-11, -5.3557946e-11, -4.765024e-10...           0
# 97  [-2.212378e-11, -4.1993617e-11, -4.2437104e-10...           1
# 98  [-2.771281e-11, -5.5143216e-11, -5.077024e-10,...           1
# 99  [-2.2376255e-11, -4.154574e-11, -3.9141812e-10...           1
#
# [100 rows x 5 columns]

# %%
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_true=df['Label'], y_pred=df['Pred_Label'])
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
n_components = 100 #maximum number of components

X = np.stack(df['Embeddings'].values)

scaler = StandardScaler()
scaler.fit(X)

X_scaled = scaler.transform(X)

pca = PCA(n_components = n_components)

pca.fit(X_scaled)
# Out:
# PCA(n_components=100)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
group = df['Label']
cdict = {0: 'red', 1: 'blue'}

Z1 = pca.transform(X_scaled)[:,0]
Z2 = pca.transform(X_scaled)[:,1]

fig, ax = plt.subplots()
for g in np.unique(group):
    ix = np.where(group == g)
    ax.scatter(Z1[ix], Z2[ix], c = cdict[g], label = g, s = 50)

plt.xlabel("First Principal Component",fontsize=14)
plt.ylabel("Second Principal Component",fontsize=14)
ax.legend()

# %%
time_start = time.time()

X_tsne = TSNE(random_state=123).fit_transform(X_scaled)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# t-SNE done! Time elapsed: 0.2770686149597168 seconds

# %%
X_tsne.shape
# Out:
# (100, 2)

# %%
color = []
for label in df['Label']:
    if label == 0:
        color.append('red')
    elif label == 1:
        color.append('blue')

plt.scatter(X_tsne[:,0] ,X_tsne[:,1], c = color)
